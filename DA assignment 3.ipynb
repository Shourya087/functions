# %% [markdown]
# #Function Assignment

# %% [markdown]
# 1. What is the difference between a function and a method in Python
# --Function is a reusable block of code which is used to carry out a specific task
# eg def sum(a,b):
#       return a+b
# method is a function in puthon but it is associated with a class and can not be usee without class object
# eg class Student:
#        def func:
#
#
# 2. Explain the concept of function arguments and parameters in Python
# --function arguments are the objects which are passed in function which have fixed value and parameter are the variables which act as arguments
# eg. def greet(greeting = "hi", name):
# here greeting is argument and name is a parameter
#
#
# 3. What are the different ways to define and call a function in Python
# --there are ways to define a function most prominently used are using def keywords or using lambda keyword
# eg def sum(a,b):
#       return a+b
#   add = lambda x,y: x+y
# calling a function can be done using arguments inside the function or using parameters
#
#
# 4. What is the purpose of the `return` statement in a Python function
# --as the output of function is inside the function body and it can not be accessed by outer body so return statement is
# used to tranfer the output of function to outer body
#
#
# 5. What are iterators in Python and how do they differ from iterables
# --iterables are the collection of  data in python which can be iterated through eg. list, tuple
# iterators are the way by which data can be iterated through iterators eg. for and while loops
#
#
# 6. Explain the concept of generators in Python and how they are defined
# --generator is used to make an iterable object which can be accessed using iter and next keyword they defined by using yield at place of return in function
#
#
# 7. What are the advantages of using generators over regular functions
# --using generator functions dont fully occupy the memory space considering if the calculation is huge or the list we want is huge and can also be faster than regular functions
#
#
# 8. What is a lambda function in Python and when is it typically used
# --lambda are the anonymous function which are defined in single line of code they are used when the computation of function is quite simple and easy
#
#
# 9. Explain the purpose and usage of the `map()` function in Python
# --purpose of map function is to apply the function to all items of an iterable it is mainly used to convert the data type of items in iterable to other
#
#
# 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python
# --map function is used to transform one data type to other , reduce is used to reduce the all items of an iterable to single output , filter is used to filter out the data according to need to user from an iterable
#
#
# 11.

# %%
#1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list
def sum_of_even(lst):
  lst = list(filter(lambda x: x%2 == 0, lst))
  return sum(lst)

sum_of_even([1,2,3,4,5,6,7])
# Out:
# 12

# %%
#2. Create a Python function that accepts a string and returns the reverse of that string
def str_reversal(str1):
    str2 = str1[::-1]
    return str2

str_reversal("shourya")
# Out:
# 'ayruohs'

# %%
#3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number
def square_of_list(lst):
  lst = list(map(lambda i: i*i, lst))
  return lst

square_of_list([1,2,3,4,5,6])
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
#4. Write a Python function that checks if a given number is prime or not from 1 to 200
a = int(input("enter number "))
def to_check_prime(a):

# %%
#5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms
def fibonacci(n):
  a = 0
  b = 1
  for i in range(n):
    yield a,b
    a,b = b , a+b

# %%
f = fibonacci(10)

# %%
next(f)
# Out:
# (0, 1)

# %%
next(f)
# Out:
# (1, 1)

# %%
next(f)
# Out:
# (1, 2)

# %%
#6. Write a generator function in Python that yields the powers of 2 up to a given exponent
def powers_of_2(p):
    for i in range(p + 1):
        yield 2 ** i
for power in powers_of_2(5):
    print(power)
# Out:
# 1
# 2
# 4
# 8
# 16
# 32

# %%
#7. implement a generator function that reads a file line by line and yields each line as a string

# %%
#8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple
tuples_list = [(1, 3), (4, 2), (2, 6), (3, 9)]
sort_tuples = sorted(tuples_list, key=lambda x: x[1])
print(sort_tuples)
# Out:
# [(4, 2), (1, 3), (2, 6), (3, 9)]

# %%
#9. Write a Python program that uses map() to convert a list of temperatures from Celsius to Fahrenheit
def c_to_f(c_list):
    return list(map(lambda c: (c * 9/5) + 32, c_list))
celsius = [0, 20, 37, 100]
\
fahrenheit = c_to_f(celsius)
print(fahrenheit)
# Out:
# [32.0, 68.0, 98.6, 212.0]

# %%
#10. Create a Python program that uses filter() to remove all the vowels from a given string
def remove_vowels(string):
    return ''.join(filter(lambda char: char.lower() not in 'aeiou', string))
text = "Hello World"
print(remove_vowels(text))
# Out:
# Hll Wrld

# %%
#11.
